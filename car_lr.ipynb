# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
df = pd.read_csv('car.csv')
df.head(398)
# Out:
#       MPG  Cylinders  Displacement Horsepower  Weight  Acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      Model Year  US Made
# 0            70        1
# 1            70        1
# 2            70        1
# 3            70        1
# 4            70        1
# ..          ...      ...
# 393          82        1
# 394          82        0
# 395          82        1
# 396          82        1
# 397          82        1
#
# [398 rows x 8 columns]

# %%
list(df.columns)
# Out:
# ['MPG',
#  'Cylinders',
#  'Displacement',
#  'Horsepower',
#  'Weight',
#  'Acceleration',
#  'Model Year',
#  'US Made']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   MPG           398 non-null    float64
#  1   Cylinders     398 non-null    int64
#  2   Displacement  398 non-null    float64
#  3   Horsepower    398 non-null    object
#  4   Weight        398 non-null    int64
#  5   Acceleration  398 non-null    float64
#  6   Model Year    398 non-null    int64
#  7   US Made       398 non-null    int64
# dtypes: float64(3), int64(4), object(1)
# memory usage: 25.0+ KB

# %%
df.describe()
# Out:
#               MPG   Cylinders  Displacement       Weight  Acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        Model Year     US Made
# count  398.000000  398.000000
# mean    76.010050    0.625628
# std      3.697627    0.484569
# min     70.000000    0.000000
# 25%     73.000000    0.000000
# 50%     76.000000    1.000000
# 75%     79.000000    1.000000
# max     82.000000    1.000000

# %%
 df['Horsepower'].unique()
# Out:
# array(['130', '165', '150', '140', '198', '220', '215', '225', '190',
#        '170', '160', '95', '97', '85', '88', '46', '87', '90', '113',
#        '200', '210', '193', '?', '100', '105', '175', '153', '180', '110',
#        '72', '86', '70', '76', '65', '69', '60', '80', '54', '208', '155',
#        '112', '92', '145', '137', '158', '167', '94', '107', '230', '49',
#        '75', '91', '122', '67', '83', '78', '52', '61', '93', '148',
#        '129', '96', '71', '98', '115', '53', '81', '79', '120', '152',
#        '102', '108', '68', '58', '149', '89', '63', '48', '66', '139',
#        '103', '125', '133', '138', '135', '142', '77', '62', '132', '84',
#        '64', '74', '116', '82'], dtype=object)

# %%
df.loc[df['Horsepower'] == '?']
# Out:
#       MPG  Cylinders  Displacement Horsepower  Weight  Acceleration  \
# 32   25.0          4          98.0          ?    2046          19.0
# 126  21.0          6         200.0          ?    2875          17.0
# 330  40.9          4          85.0          ?    1835          17.3
# 336  23.6          4         140.0          ?    2905          14.3
# 354  34.5          4         100.0          ?    2320          15.8
# 374  23.0          4         151.0          ?    3035          20.5
#
#      Model Year  US Made
# 32           71        1
# 126          74        1
# 330          80        0
# 336          80        1
# 354          81        0
# 374          82        1

# %%
df = df.drop(labels = [32,126,330,336,354,374] , axis = 0 )

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 392 entries, 0 to 397
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   MPG           392 non-null    float64
#  1   Cylinders     392 non-null    int64
#  2   Displacement  392 non-null    float64
#  3   Horsepower    392 non-null    object
#  4   Weight        392 non-null    int64
#  5   Acceleration  392 non-null    float64
#  6   Model Year    392 non-null    int64
#  7   US Made       392 non-null    int64
# dtypes: float64(3), int64(4), object(1)
# memory usage: 27.6+ KB

# %%
df['Horsepower'] = pd.to_numeric(df['Horsepower'])

# %%
cols = df.columns

# %%
# copy the data
df_min_max_scaled = df.copy()
  
# apply normalization techniques by Column 

for i in cols:
    df_min_max_scaled[i] = (df_min_max_scaled[i] - df_min_max_scaled[i].min()) / (df_min_max_scaled[i].max() - df_min_max_scaled[i].min())    
  
# view normalized data
display(df_min_max_scaled)
# Out:
#           MPG  Cylinders  Displacement  Horsepower    Weight  Acceleration  \
# 0    0.239362        1.0      0.617571    0.456522  0.536150      0.238095
# 1    0.159574        1.0      0.728682    0.646739  0.589736      0.208333
# 2    0.239362        1.0      0.645995    0.565217  0.516870      0.178571
# 3    0.186170        1.0      0.609819    0.565217  0.516019      0.238095
# 4    0.212766        1.0      0.604651    0.510870  0.520556      0.148810
# ..        ...        ...           ...         ...       ...           ...
# 393  0.478723        0.2      0.186047    0.217391  0.333711      0.452381
# 394  0.930851        0.2      0.074935    0.032609  0.146583      0.988095
# 395  0.611702        0.2      0.173127    0.206522  0.193365      0.214286
# 396  0.505319        0.2      0.134367    0.179348  0.286929      0.630952
# 397  0.585106        0.2      0.131783    0.195652  0.313864      0.678571
#
#      Model Year  US Made
# 0           0.0      1.0
# 1           0.0      1.0
# 2           0.0      1.0
# 3           0.0      1.0
# 4           0.0      1.0
# ..          ...      ...
# 393         1.0      1.0
# 394         1.0      0.0
# 395         1.0      1.0
# 396         1.0      1.0
# 397         1.0      1.0
#
# [392 rows x 8 columns]

# %%
df1 = df_min_max_scaled.reset_index()
df1.drop( labels = ['index'] , axis = 1)
# Out:
#           MPG  Cylinders  Displacement  Horsepower    Weight  Acceleration  \
# 0    0.239362        1.0      0.617571    0.456522  0.536150      0.238095
# 1    0.159574        1.0      0.728682    0.646739  0.589736      0.208333
# 2    0.239362        1.0      0.645995    0.565217  0.516870      0.178571
# 3    0.186170        1.0      0.609819    0.565217  0.516019      0.238095
# 4    0.212766        1.0      0.604651    0.510870  0.520556      0.148810
# ..        ...        ...           ...         ...       ...           ...
# 387  0.478723        0.2      0.186047    0.217391  0.333711      0.452381
# 388  0.930851        0.2      0.074935    0.032609  0.146583      0.988095
# 389  0.611702        0.2      0.173127    0.206522  0.193365      0.214286
# 390  0.505319        0.2      0.134367    0.179348  0.286929      0.630952
# 391  0.585106        0.2      0.131783    0.195652  0.313864      0.678571
#
#      Model Year  US Made
# 0           0.0      1.0
# 1           0.0      1.0
# 2           0.0      1.0
# 3           0.0      1.0
# 4           0.0      1.0
# ..          ...      ...
# 387         1.0      1.0
# 388         1.0      0.0
# 389         1.0      1.0
# 390         1.0      1.0
# 391         1.0      1.0
#
# [392 rows x 8 columns]

# %%
df1.describe()
# Out:
#             index         MPG   Cylinders  Displacement  Horsepower  \
# count  392.000000  392.000000  392.000000    392.000000  392.000000
# mean   197.579082    0.384200    0.494388      0.326646    0.317768
# std    114.534637    0.207580    0.341157      0.270398    0.209191
# min      0.000000    0.000000    0.000000      0.000000    0.000000
# 25%     98.750000    0.212766    0.200000      0.095607    0.157609
# 50%    197.500000    0.365691    0.200000      0.214470    0.258152
# 75%    295.250000    0.531915    1.000000      0.536822    0.434783
# max    397.000000    1.000000    1.000000      1.000000    1.000000
#
#            Weight  Acceleration  Model Year     US Made
# count  392.000000    392.000000  392.000000  392.000000
# mean     0.386897      0.448888    0.498299    0.625000
# std      0.240829      0.164218    0.306978    0.484742
# min      0.000000      0.000000    0.000000    0.000000
# 25%      0.173589      0.343750    0.250000    0.000000
# 50%      0.337539      0.446429    0.500000    1.000000
# 75%      0.567550      0.537202    0.750000    1.000000
# max      1.000000      1.000000    1.000000    1.000000

# %%
x = df1.drop(labels = ['MPG'],axis = 1)
y = df1['MPG']

# %%
x
# Out:
#      index  Cylinders  Displacement  Horsepower    Weight  Acceleration  \
# 0        0        1.0      0.617571    0.456522  0.536150      0.238095
# 1        1        1.0      0.728682    0.646739  0.589736      0.208333
# 2        2        1.0      0.645995    0.565217  0.516870      0.178571
# 3        3        1.0      0.609819    0.565217  0.516019      0.238095
# 4        4        1.0      0.604651    0.510870  0.520556      0.148810
# ..     ...        ...           ...         ...       ...           ...
# 387    393        0.2      0.186047    0.217391  0.333711      0.452381
# 388    394        0.2      0.074935    0.032609  0.146583      0.988095
# 389    395        0.2      0.173127    0.206522  0.193365      0.214286
# 390    396        0.2      0.134367    0.179348  0.286929      0.630952
# 391    397        0.2      0.131783    0.195652  0.313864      0.678571
#
#      Model Year  US Made
# 0           0.0      1.0
# 1           0.0      1.0
# 2           0.0      1.0
# 3           0.0      1.0
# 4           0.0      1.0
# ..          ...      ...
# 387         1.0      1.0
# 388         1.0      0.0
# 389         1.0      1.0
# 390         1.0      1.0
# 391         1.0      1.0
#
# [392 rows x 8 columns]

# %%
 X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=42)

# %%
reg = LinearRegression().fit(X_train, y_train)

# %%
y_pred = reg.predict(X_test)
y_pred
# Out:
# array([ 0.48242696,  0.47351222,  0.68914428,  0.39995785,  0.49932814,
#         0.5634025 , -0.01172452,  0.56836784,  0.31817665,  0.55115386,
#         0.09826889,  0.41838694,  0.20784106,  0.54654518,  0.36178779,
#         0.54433329,  0.30820313,  0.64336458,  0.45572776,  0.58457427,
#         0.2561787 ,  0.71135597,  0.70662224,  0.16802093,  0.55098963,
#         0.47104219,  0.352858  ,  0.19378526,  0.56922936,  0.4381071 ,
#         0.12574469,  0.38514796,  0.31178512,  0.60186243,  0.10324436,
#         0.72155827,  0.04181078,  0.41319708,  0.06083121, -0.0703491 ,
#         0.1015693 ,  0.52197191,  0.73492597,  0.49427633,  0.08568169,
#         0.0301852 ,  0.22222285,  0.62296741,  0.39682321,  0.6052787 ,
#         0.07895267,  0.47732474,  0.37906897,  0.69723541,  0.50508643,
#         0.23156016,  0.30148779,  0.36004377,  0.39151163,  0.45879092,
#        -0.00619458,  0.3661581 ,  0.42309167,  0.40840616,  0.54464063,
#         0.57947541,  0.44068759,  0.57580545,  0.34891401,  0.03525728,
#         0.35498862,  0.12991633,  0.45966723,  0.49035882,  0.38833802,
#         0.38100654,  0.12388997,  0.16217301,  0.43457621,  0.29874004,
#         0.4297306 ,  0.31477666,  0.09559408,  0.6379633 ,  0.16676462,
#         0.69817665,  0.46812306,  0.38876122,  0.21213092,  0.20957178,
#         0.43866091,  0.50779853,  0.61471229,  0.54514772,  0.32732653,
#         0.26817316,  0.3414543 ,  0.02647821,  0.53947111,  0.26418301,
#         0.02209705,  0.20109719,  0.03066781,  0.51649236,  0.52637815,
#         0.60780105,  0.74856955,  0.41900953,  0.40084489,  0.29527743,
#         0.72703802,  0.66476675,  0.40094716,  0.3539541 ,  0.68616702,
#         0.58498116,  0.29202687,  0.36364279])

# %%
y_test
# Out:
# 78     0.452128
# 274    0.335106
# 246    0.720745
# 55     0.452128
# 387    0.478723
#          ...
# 79     0.345745
# 310    0.750000
# 352    0.635638
# 248    0.276596
# 153    0.159574
# Name: MPG, Length: 118, dtype: float64

# %%
mse = mean_squared_error(y_test, y_pred).round(2)
rmse = (mse**.5).round(2)
print(mse)
print(rmse)
# Out:
# 0.01
# 0.1

# %%
mae = mean_absolute_error(y_test, y_pred).round(2)
mae
# Out:
# 0.07

# %%
r2_score(y_test, y_pred)
# Out:
# 0.8074857456612935
